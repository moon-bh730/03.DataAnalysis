# %% [markdown]
# # Matplotlib에서 한글 폰트 사용하기

# %% [markdown]
# ## 1. Colab 환경 - 별도 정리

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 한글이 깨짐
plt.title("플롯 예")
plt.plot([0,1,4,9])
plt.show()

# %% [markdown]
# ## 2. Loca
