# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\범희\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\범희\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
from PIL import Image
import numpy as np

# %%
maskfile = Image.open('data/Tesla3.png')

# %%
with open("data/tesla.txt", 'rt', encoding='UTF8') as fp:
    text = fp.read()

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
stop_words.add('said')

# %%
wc = WordCloud(font_path='data/NanumGothic.ttf', background_color='white',
            max_words=1000, stopwords=stop_words)

#wordcloud = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', colormap='winter', stopwords=stop_words).generate(text)
wc.generate(text)

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(keys[i], ':', values[i])
# Out:
# 테슬라 : 1.0
# 테슬라 모델3 : 0.68
# 테슬라 모델Y : 0.19
# 전 : 0.18
# 전기차 : 0.18
# 테슬라가 : 0.16
# 테슬라의 : 0.13
# 테슬라는 : 0.11
# 대한 : 0.11
# 입니다 : 0.09

# %%
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
mask = np.array(Image.open('data/Tesla3.png'))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(font_path='data/NanumGothic.ttf',background_color='white', mask=mask,
               max_words=1000, stopwords=stop_words)
wc.generate(text)

# %%
plt.figure(figsize=(13,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
with open("data/tesla.txt") as fp:
    text = fp.read()

maskfile = Image.open('data/Stormtrooper_mask.png')

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# 전체 본문을 읽는다.
with open("data/tesla.txt", 'rt', encoding='UTF8') as fp:
    text = fp.read()

# text = open("data/tesla.txt").read()

maskfile = Image.open('data/Tesla3.png')

stopwords = set(STOPWORDS)
stopwords.add("said")

# wc = WordCloud(font_path='data/NanumGothic.ttf', background_color="white", max_words=2000, mask=maskfile,
#                stopwords=stopwords, contour_width=3, contour_color='steelblue')
wc = WordCloud(font_path='data/NanumGothic.ttf', background_color='white',
            max_words=1000, stopwords=stop_words)

# World cloud 이미지 생성
wc.generate(text)

# 파일에 저장하기
wc.to_file("data/tesla_.png")

# show
# plt.imshow(wc, interpolation='bilinear')
# plt.axis("off")
# plt.figure()
# plt.imshow(maskfile, cmap=plt.cm.gray, interpolation='bilinear')
# plt.axis("off")
# plt.show()

plt.figure(figsize=(13,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
with open("data/tesla.txt", 'rt', encoding='UTF8') as fp:
    text = fp.read()

# %%
maskfile = Image.open('data/tesla4.png')

# %%
with open("data/tesla.txt", 'rt', encoding='UTF8') as fp:
    text = fp.read()
text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

# %%
from wordcloud import STOPWORDS
stop_words = set(STOPWORDS)
stop_words.add('int')
stop_words.add('ext')
len(stop_words)
# Out:
# 194

# %%
mask = np.array(Image.open('data/tesla4.png'))
wc = WordCloud(font_path='data/NanumGothic.ttf',mask=mask, max_words=1000, stopwords=stop_words,
               margin=10, random_state=2021)
wc.generate(text)
default_colors = wc.to_array

# %%
mask = np.array(Image.open('data/tesla4.png'))
wc = WordCloud(font_path='data/NanumGothic.ttf',mask=mask, max_words=1000, stopwords=stop_words,
               margin=10, random_state=2021)
wc.generate(text)
default_colors = wc.to_array

# %%
import random
def grey_color(word, font_size, position,
               orientation, random_state=None, **kwargs):
    return f'hsl(0, 0%, {random.randint(60,100)}%)'

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color, random_state=2021), 
           interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from PIL import Image
from wordcloud import WordCloud

import numpy as np

# 전체 본문을 읽는다.
with open("data/tesla.txt", 'rt', encoding='UTF8') as fp:
     text = fp.read()

# mask 이미지를 읽는다.
maskfile = np.array(Image.open('data/Tesla.png'))
# plt.imshow(maskfile, cmap=plt.cm.gray, interpolation='bilinear')
# plt.axis('off')
# plt.show()

wc = WordCloud(font_path='data/NanumGothic.ttf', background_color="white", max_words=20000, mask=maskfile, max_font_size=300).generate(text)
wc.generate(text)

# wc.to_file('test.png')

plt.figure(figsize=(10,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.savefig("6회_문범희_테슬라.png")
plt.show()
